# %%
import numpy as np
import matplotlib.pyplot as plt
#import plotly.express as px
import pandas as pd
accuracy = []
#from sin_generator import *

# %%
ctype = 'blegnj'
snr = 8
plt.title(ctype + str(snr))
plt.plot(data,label='Accuracy '+acc)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # NICE PLOTTING STUFF

# %%
with open('result_new_datalenvar.txt') as f:
    lines = f.readlines()

for i in range(299, len(lines),5):
    #print(i,lines[i])
    ctype=lines[i]
    #print(ctype)
    ctype=ctype.split(' ')
    try:
        circ=ctype[5]#
        snr = ctype[10]
        #print(snr)
        #print(ctype)
        #print(ctype.split(' '))
        txt=lines[i+1]
        acc=lines[i+3]
      
        acc=acc.split(':')
        acc=acc[1]
        acc=acc.replace("\n","")
        acc=float(acc)
        acc=acc*100
        acc=round(acc,2)
        accuracy.append(acc)
        acc=str(acc) + '%' 
        #print(acc)
        
        #print(txt)
        txt=txt.replace("]","")
        txt=txt.replace("[","")
        txt=txt.replace("\n","")

        data=[float(x) for x in txt.strip().split(',')]
        plt.title(circ + ' ' + str(snr))
        plt.plot(data,label='Accuracy '+acc)
        plt.xlabel('Iteration')
        plt.ylabel('Cost_FN')
        plt.legend()
        ##plt.legend(acc)
        plt.show()
    except:
        #ctype=ctype[4]
        #print(lines[i])
        ctype=lines[i]
        ctype=ctype.strip(':')
        ctype=ctype.split(' ')
        circ=ctype[3]
        snr = ctype[10]
        #print(ctype.replace(':',''))
        #print(ctype.split(' '))
        #print(lines[i+1])
        txt=lines[i+1]
        txt=txt.replace("]","")
        txt=txt.replace("[","")
        txt=txt.replace("\n","")
        acc=lines[i+3]

        acc=acc.split(':')
        acc=acc[1]
        acc=acc.replace("\n","")
        acc=float(acc)
        acc=acc*100
        acc=round(acc,2)
        acc=str(acc) + '%' 
        data=[float(x) for x in txt.strip().split(',')]
        plt.title(circ + ' ' + str(snr))
        plt.plot(data,label='Accuracy '+acc)
        plt.xlabel('Iteration')
        plt.ylabel('Loss')
        plt.legend()
        plt.show()

# %%
print(len(accuracy))

plt.title()
plt.plot(data,label='Accuracy '+acc)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 21
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\owner\qml_sin\Result\results.ipynb Cell 5 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/owner/qml_sin/Result/results.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> print(len(accuracy))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/owner/qml_sin/Result/results.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> plt.title()
#       <a href='vscode-notebook-cell:/c%3A/Users/owner/qml_sin/Result/results.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> plt.plot(data,label='Accuracy '+acc)
#       <a href='vscode-notebook-cell:/c%3A/Users/owner/qml_sin/Result/results.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> plt.xlabel('Iteration')
#
# TypeError: title() missing 1 required positional argument: 'label'

# %%
with open('r2.txt') as f:
    lines = f.readlines()
SNR=[3,0]
cc=['tab:blue','tab:orange']
ii=0
for i in range(0, len(lines),5):
    #print(i,lines[i])
    ctype=lines[i]
    #print(ctype)
    ctype=ctype.split(' ')
    try:
        ctype=ctype[5]
        #print(ctype)
        #print(ctype.split(' '))
        txt=lines[i+1]
        acc=lines[i+3]
        
        acc=acc.split(':')
        acc=acc[1]
        acc=acc.replace("\n","")
        acc=float(acc)
        acc=acc*100
        acc=round(acc,2)
        acc=str(acc) + '%'
        #print(acc)
        
        
        #print(txt)
        txt=txt.replace("]","")
        txt=txt.replace("[","")
        txt=txt.replace("\n","")

        data=[float(x) for x in txt.strip().split(',')]
        plt.title(ctype)
        #plt.plot(data,label='Accuracy '+acc)
        plt.plot(data,label='SNR:'+str(SNR[ii])+' Accuracy '+acc,color=cc[ii])
        #if SNR[ii] == 3:
        #    plt.plot(data,label='SNR:'+str(SNR[ii])+' Accuracy '+acc,color='tab:blue')
        #else:
        #    plt.plot(data,label='SNR:'+str(SNR[ii])+' Accuracy '+acc,color='tab:orange')
        ii=ii+1
        plt.xlabel('Iteration')
        plt.ylabel('Cost_FN')
        plt.legend()
        ##plt.legend(acc)
        #plt.show()
    except:
        #ctype=ctype[4]
        #print(lines[i])
        ctype=lines[i]
        ctype=ctype.strip(':')
        ctype=ctype.split(' ')
        ctype=ctype[3]
        #print(ctype.replace(':',''))
        #print(ctype.split(' '))
        #print(lines[i+1])
        txt=lines[i+1]
        txt=txt.replace("]","")
        txt=txt.replace("[","")
        txt=txt.replace("\n","")
        acc=lines[i+2]
        
        acc=acc.split(':')
        acc=acc[1]
        acc=acc.replace("\n","")
        acc=float(acc)
        acc=acc*100
        acc=round(acc,2)
        acc=str(acc) + '%'
        data=[float(x) for x in txt.strip().split(',')]
        plt.title(ctype)
        plt.plot(data,label='SNR:'+str(SNR[ii])+' Accuracy '+acc,color=cc[ii])
        plt.xlabel('Iteration')
        plt.ylabel('Loss')
        plt.legend()
        #ii=ii+1
plt.show()

# %%
with open(r'CNN_qdata_compare.txt') as f:
    lines = f.readlines()
SNR=[i for i in range(0,20)]
cc=['tab:orange','tab:blue']
ii=0
ancm=[]
for i in range(0, len(lines),5):
    #print(i,lines[i])
    ctype=lines[i]
    #print(ctype)
    ctype=ctype.split(' ')
    try:
        ctype=ctype[5]
        #print(ctype)
        #print(ctype.split(' '))
        txt=lines[i+1]
        acc=lines[i+3]
        
        acc=acc.split(':')
        acc=acc[1]
        acc=acc.replace("\n","")
        acc=float(acc)
        acc=acc*100
        acc=round(acc,2)
        acc=str(acc) + '%'
        #print(acc)
        
        
        #print(txt)
        txt=txt.replace("]","")
        txt=txt.replace("[","")
        txt=txt.replace("\n","")

        data=[float(x) for x in txt.strip().split(',')]
        plt.title(ctype)
        #plt.plot(data,label='Accuracy '+acc)
        if SNR[ii] == 3:
            plt.plot(data,label='SNR:'+str(SNR[ii])+' Accuracy '+acc,color='tab:blue')
        else:
            plt.plot(data,label='SNR:'+str(SNR[ii])+' Accuracy '+acc,color='tab:orange')
        ii=ii+1
        plt.xlabel('Iteration')
        plt.ylabel('Cost_FN')
        plt.legend()
        ##plt.legend(acc)
        #plt.show()
    except:
        #ctype=ctype[4]
        #print(lines[i])
        ctype=lines[i]
        ctype=ctype.strip(':')
        ctype=ctype.split(' ')
        ctype=ctype[3]
        #print(ctype.replace(':',''))
        #print(ctype.split(' '))
        #print(lines[i+1])
        txt=lines[i+1]
        txt=txt.replace("]","")
        txt=txt.replace("[","")
        txt=txt.replace("\n","")
        acc=lines[i+2]
        
        acc=acc.split(':')
        acc=acc[1]
        acc=acc.replace("\n","")
        acc=float(acc)
        anc=acc
        ancm=ancm+[acc]
        acc=acc*100
        acc=round(acc,2)
        acc=str(acc) + '%'
        data=[float(x) for x in txt.strip().split(',')]
        plt.title(ctype)
        plt.plot(data,label='SNR:'+str(SNR[ii])+' Accuracy '+acc,color=cc[ii])
        plt.xlabel('Iteration')
        plt.ylabel('Loss')
        plt.legend()
        #ii=ii+1
plt.show()

# %%
plt.plot([i for i in range(0,len(ancm))],ancm)
plt.ylabel('Accuray')
plt.xlabel('SNR')
plt.show()

# %%
with open('result all new.txt') as f:
    lines = f.readlines()

plt.figure(figsize=(20,10))

for i in range(0,len(lines),4):
    #print('1',lines[i])
    
    #data=np.genfromtxt(lines[i+1], delimiter=',')
    txt=lines[i+1]
    txt=txt.replace("]","")
    txt=txt.replace("[","")
    txt=txt.replace("\n","")
    data=[float(x) for x in txt.strip().split(',')]
    plt.plot(data,)
    plt.xlabel('Iteration')
    plt.ylabel('Cost_FN')
    #plt.legend(lines[i+2])
    #plt.title(lines[i])
    tt=lines[i]
    tt=tt.split(' ')
    #print(tt[5])
    tt=tt[5]
    #tt=tt.replace('_','')
    plt.plot(data,label=tt)
    #print('2',lines[i+1])
    print(tt)
plt.legend()



    #plt.figtext(0.5, 0.001, lines[i+2], ha="center", fontsize=18, bbox={"facecolor":"orange", "alpha":0.5, "pad":3})
    #print('3',lines[i+2])
plt.show()
    #break
# Out:
# U_TTN
# U_5
# U_6
# U_9
# U_13
# U_14
# U_15
# U_SO4
# U_SU4
# U_SU4_no_pooling
# U_SU4_1D
# U_9_1D
# U_TTN

# %%
with open('result all new.txt') as f:
    lines = f.readlines()

df=pd.DataFrame()
j=0
for i in range(0,len(lines),4):
  
    txt=lines[i+1]
    txt=txt.replace("]","")
    txt=txt.replace("[","")
    txt=txt.replace("\n","")
    data=[float(x) for x in txt.strip().split(',')]

    #plt.legend(lines[i+2])
    #plt.title(lines[i])
    #print(lines[i+2])
    ac=lines[i+2]
    ac=ac.split(':')
    ac=ac[1]
    #print(ac)
    tt=lines[i]
    tt=tt.split(' ')
    

    tt=tt[5]
    j=0
    for item in data:
        df=df.append({'cost_fn':item,'type':tt,'i':j},ignore_index=True)
        j=j+1
    #try:
    #    df.insert(j,tt, data )
    #except:
    #    pass
    #j=j+1
# Out:
# /var/folders/_9/cq7vvqfn6sn9slxm7gyzpjm00000gn/T/ipykernel_6417/1638627419.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /var/folders/_9/cq7vvqfn6sn9slxm7gyzpjm00000gn/T/ipykernel_6417/1638627419.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /var/folders/_9/cq7vvqfn6sn9slxm7gyzpjm00000gn/T/ipykernel_6417/1638627419.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /var/folders/_9/cq7vvqfn6sn9slxm7gyzpjm00000gn/T/ipykernel_6417/1638627419.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /var/folders/_9/cq7vvqfn6sn9slxm7gyzpjm00000gn/T/ipykernel_6417/1638627419.py:28: FutureWarning:
#
# ...

# %%
df
# Out:
#         cost_fn   type
# 0     16.888128  U_TTN
# 1     16.674387  U_TTN
# 2     16.694642  U_TTN
# 3     16.672911  U_TTN
# 4     16.445138  U_TTN
# ...         ...    ...
# 2595  13.159403  U_TTN
# 2596  13.615965  U_TTN
# 2597  13.501366  U_TTN
# 2598  15.235647  U_TTN
# 2599  14.040024  U_TTN
#
# [2600 rows x 2 columns]

# %%
fig = px.line(df, x='i', y='cost_fn',color='type')
fig.show()

# %%
signal_data=sin_gen_2()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig, ax = plt.subplots()

ax.set_ylim(-2,2)
x = np.linspace(0,2*np.pi,256)
da=signal_data[0][0]
#da=da[0]
line, = ax.plot(x, )
line2, = ax.plot(x, )


def animate(i):
    if i % 1000 ==0:
        print(i)
    #print(i)
    da=signal_data[0][i]
    #da=signal_data[0][0]
    #print(da)
    line.set_ydata(da)  # update the data.
    if signal_data[1][i] == 1:
        #print(signal_data[1][i])
        line.set_color('b')
    else:
        line.set_color('r')
    #da=signal_data[0][i+5000]
    #line2, = ax.plot(da)
    return line,


ani = animation.FuncAnimation(
    fig, animate, interval=10, blit=True, save_count=10000)

writer = animation.FFMpegWriter(
     fps=15, metadata=dict(artist='Me'), bitrate=1800)
ani.save("movie test 2t a.mp4", writer=writer)
# Out:
# 0
# 0
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000

# %%
)
    line.set_ydata(x,da)  # update the data.
    return line,


ani = animation.FuncAnimation(
    fig, animate, interval=10, blit=True, save_count=50)

writer = animation.FFMpegWriter(
     fps=5, metadata=dict(artist='Me'), bitrate=1800)
ani.save("movie test.mp4", writer=writer)

# %%
signal_data[0][i]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/_9/cq7vvqfn6sn9slxm7gyzpjm00000gn/T/ipykernel_6417/581403123.py in <module>
# ----> 1 signal_data[0][i]
#
# TypeError: list indices must be integers or slices, not list

# %%
import matplotlib
from matplotlib import animation
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation



fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 5))
 
# set limit for x and y axis
axes.set_ylim(-2, 2)
axes.set_xlim(-2, 2)
 
x = np.linspace(0,2*np.pi,256)
# style for plotting line
plt.style.use("ggplot")
 
# create 5 list to get store element
# after every iteration
#x1, y1, y2, y3, y4 = [], [], [], [], []
#myvar = count(0, 3)
 
def animate(i):
    #x1.append(next(myvar))
    #y1.append((l1[i]))
    #y2.append((l2[i]))
    #y3.append((l3[i]))
    #y4.append((l4[i]))
    x = np.linspace(0,2*np.pi,256)
    da1=signal_data[0][i]
    da2=signal_data[0][i+5000]
    axes.plot(x, da1, color="red")
    #axes.plot(x1, y2, color="gray")
    axes.plot(x, da2, color="blue")
    #axes.plot(x1, y4, color="green")
 
 
# set ani variable to call the
# function recursively
anim = FuncAnimation(fig, animate, interval=30, blit=False, repeat = False)


writer = animation.FFMpegWriter(
     fps=15, metadata=dict(artist='Me'), bitrate=1800)
anim.save("movie test 4.mp4", writer=writer)

# %%
import pennylane as qml

# This module contains the set of unitary ansatze that will be used to benchmark the performances of Quantum Convolutional Neural Network (QCNN) in QCNN.ipynb module


# Unitary Ansatze for Convolutional Layer
def U_TTN(params, wires):  # 2 params
    qml.RY(params[0], wires=wires[0])
    qml.RY(params[1], wires=wires[1])
    qml.CNOT(wires=[wires[0], wires[1]])

# %%
dev = qml.device('lightning.qubit', wires=(0,1,2,3,4,5,6,7,8))

@qml.qnode(dev)
def U_SU4(params, wires): # 15 params
    print(params,wires)
    qml.U3(params[0], params[1], params[2], wires=wires[0])
    qml.U3(params[3], params[4], params[5], wires=wires[1])
    qml.CNOT(wires=[wires[0], wires[1]])
    qml.RY(params[6], wires=wires[0])
    qml.RZ(params[7], wires=wires[1])
    qml.CNOT(wires=[wires[1], wires[0]])
    qml.RY(params[8], wires=wires[0])
    qml.CNOT(wires=[wires[0], wires[1]])
    qml.U3(params[9], params[10], params[11], wires=wires[0])
    qml.U3(params[12], params[13], params[14], wires=wires[1])
